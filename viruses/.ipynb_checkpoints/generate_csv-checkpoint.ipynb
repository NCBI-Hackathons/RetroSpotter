# %%
import glob
import pandas as pd
import re
from Bio import Entrez
import time
import xml.etree.ElementTree as ET
import seaborn as sns
import copy
import numpy as np
from Bio import SeqIO

# %%
# Edit the locations below to the location of your two results folders.

files_disease = glob.glob('aml_results/*hitcount.txt')
files_control = glob.glob('control_results/*hitcount.txt')

location_of_fasta = '../test_sequences/retroviruses.fasta'

# %%
#List of sequences in the reference FASTA
fasta_ids = []

with open(location_of_fasta, "r") as handle:
    for record in SeqIO.parse(handle, "fasta") :
        fasta_ids.append(record.id)

# %%
#Get read hit counts from disease folder

master_list = []

for file in files_disease:
    
    list_of_seqs = copy.deepcopy(fasta_ids)
    
    name = str(file)
    
    with open(file, "r") as ifile:
        
        for line in ifile:
            
            data = line.strip().split(' ')
            data = data+[name, 'disease']
            
            list_of_seqs.remove(data[1])
            
            
            master_list.append(data)
            
    for seq in list_of_seqs:
        
        data = [0, seq, name, 'disease']
        
        master_list.append(data)

# %%
#Get read hit counts from control folder

for file in files_control:
    
    name = str(file)
    
    list_of_seqs = copy.deepcopy(sequences)
    
    with open(file, "r") as ifile:
        
        for line in ifile:
            
            data = line.strip().split(' ')
            data = data+[name, 'control']
            master_list.append(data)
            
            
    for seq in list_of_seqs:
        
        data = [0, seq, name, 'control']
        
        master_list.append(data)

# %%
df = pd.DataFrame(columns=['count', 'seq', 'file', 'type'], data= master_list)

# %%
def get_srr_accession(df):
    """
    Extract the SRR number from the file_location field of the dataframe.
    """
    pattern = re.compile(r"[SE]RR[0-9]+")

    file = df['file']

    return re.search(pattern, file).group(0)

# %%
df['acc'] = df.apply(get_srr_accession, axis=1)

# %%
df['count'] = df['count'].astype(int)

# %%
pivoted_data = df.pivot_table(index='file',columns='seq', values='count')

# %%
pivoted_data.head()
# Out:
# seq                                          AB052567.1  AB052568.1  \
# file
# aml_results/aml.SRR1036002.sam.hitcount.txt         0.0         0.0
# aml_results/aml.SRR1036003.sam.hitcount.txt         0.0         0.0
# aml_results/aml.SRR1036004.sam.hitcount.txt         0.0         4.0
# aml_results/aml.SRR1036005.sam.hitcount.txt         0.0         0.0
# aml_results/aml.SRR1036006.sam.hitcount.txt         0.0         0.0
#
# seq                                          AB052569.1  AB052570.1  \
# file
# aml_results/aml.SRR1036002.sam.hitcount.txt         0.0         0.0
# aml_results/aml.SRR1036003.sam.hitcount.txt         0.0         0.0
# aml_results/aml.SRR1036004.sam.hitcount.txt         5.0         0.0
# aml_results/aml.SRR1036005.sam.hitcount.txt         0.0         0.0
# aml_results/aml.SRR1036006.sam.hitcount.txt         0.0         0.0
#
# seq                                          AB052571.1  AB052572.1  \
# file
# aml_results/aml.SRR1036002.sam.hitcount.txt         0.0         0.0
# aml_results/aml.SRR1036003.sam.hitcount.txt         0.0         0.0
# aml_results/aml.SRR1036004.sam.hitcount.txt         2.0         2.0
# aml_results/aml.SRR1036005.sam.hitcount.txt         0.0         0.0
# aml_results/aml.SRR1036006.sam.hitcount.txt         0.0         0.0
#
# seq                                          AB052573.1  AB052574.1  \
# file
# aml_results/aml.SRR1036002.sam.hitcount.txt         0.0         0.0
# aml_results/aml.SRR1036003.sam.hitcount.txt         0.0         0.0
# aml_results/aml.SRR1036004.sam.hitcount.txt         5.0         0.0
# aml_results/aml.SRR1036005.sam.hitcount.txt         0.0         0.0
# aml_results/aml.SRR1036006.sam.hitcount.txt         0.0         0.0
#
# seq                                          AB052575.1  AB052576.1  \
# file
# aml_results/aml.SRR1036002.sam.hitcount.txt         0.0         0.0
# aml_results/aml.SRR1036003.sam.hitcount.txt         0.0         0.0
# aml_results/aml.SRR1036004.sam.hitcount.txt         0.0         2.0
# aml_results/aml.SRR1036005.sam.hitcount.txt         0.0         0.0
# aml_results/aml.SRR1036006.sam.hitcount.txt         0.0         0.0
#
# seq                                               ...        XM_017007612.2  \
# file                                              ...
# aml_results/aml.SRR1036002.sam.hitcount.txt       ...                   0.0
# aml_results/aml.SRR1036003.sam.hitcount.txt       ...                   0.0
# aml_results/aml.SRR1036004.sam.hitcount.txt       ...                   4.0
# aml_results/aml.SRR1036005.sam.hitcount.txt       ...                   0.0
# aml_results/aml.SRR1036006.sam.hitcount.txt       ...                   0.0
#
# seq                                          XM_017007613.2  XM_017007614.2  \
# file
# aml_results/aml.SRR1036002.sam.hitcount.txt             0.0             0.0
# aml_results/aml.SRR1036003.sam.hitcount.txt             0.0             0.0
# aml_results/aml.SRR1036004.sam.hitcount.txt             2.0             4.0
# aml_results/aml.SRR1036005.sam.hitcount.txt             0.0             0.0
# aml_results/aml.SRR1036006.sam.hitcount.txt             0.0             0.0
#
# seq                                          XM_017007620.2  XM_017012936.1  \
# file
# aml_results/aml.SRR1036002.sam.hitcount.txt             0.0             0.0
# aml_results/aml.SRR1036003.sam.hitcount.txt             0.0             0.0
# aml_results/aml.SRR1036004.sam.hitcount.txt             0.0            38.0
# aml_results/aml.SRR1036005.sam.hitcount.txt             0.0             0.0
# aml_results/aml.SRR1036006.sam.hitcount.txt             0.0             0.0
#
# seq                                          XM_017017016.1  XM_017027549.1  \
# file
# aml_results/aml.SRR1036002.sam.hitcount.txt             0.0             0.0
# aml_results/aml.SRR1036003.sam.hitcount.txt             0.0             0.0
# aml_results/aml.SRR1036004.sam.hitcount.txt             8.0             0.0
# aml_results/aml.SRR1036005.sam.hitcount.txt             0.0             0.0
# aml_results/aml.SRR1036006.sam.hitcount.txt             0.0             0.0
#
# seq                                          XM_024453864.1  XM_024453865.1  \
# file
# aml_results/aml.SRR1036002.sam.hitcount.txt             0.0             0.0
# aml_results/aml.SRR1036003.sam.hitcount.txt             0.0             0.0
# aml_results/aml.SRR1036004.sam.hitcount.txt             4.0             4.0
# aml_results/aml.SRR1036005.sam.hitcount.txt             0.0             0.0
# aml_results/aml.SRR1036006.sam.hitcount.txt             0.0             0.0
#
# seq                                          XM_024453866.1
# file
# aml_results/aml.SRR1036002.sam.hitcount.txt             0.0
# aml_results/aml.SRR1036003.sam.hitcount.txt             0.0
# aml_results/aml.SRR1036004.sam.hitcount.txt             2.0
# aml_results/aml.SRR1036005.sam.hitcount.txt             0.0
# aml_results/aml.SRR1036006.sam.hitcount.txt             0.0
#
# [5 rows x 275 columns]

# %%
def get_spot_count(df, email, max_errors):
    """
    Use the Entrez API to get the spot (read) count for that SRR number.
    """

    srr_acc = df['acc']
    
    print (srr_acc)

    # get SRR id
    Entrez.email = email

    error_count =0

    while error_count < max_errors:

        try:

            handle = Entrez.esearch(db="sra",term=srr_acc)

            record = Entrez.read(handle)

            handle.close()

            srr_id = record["IdList"][0]

            break

        except:

            print ('error occured collecting ID ', srr_acc, error_count)

            time.sleep(10)

            error_count = error_count +1


    # get SRR summary

    error_count =0

    while error_count < max_errors:

        try:

            handle = Entrez.esummary(db='sra', id=srr_id)

            record = Entrez.read(handle)

            handle.close()

            my_xml = record[0]['Runs']

            # Parse XML
            xml_object = ET.fromstringlist(["<root>", my_xml, "</root>"])

            # Get total_spots (reads)
            for child in xml_object:

                if child.attrib['acc'] == srr_acc:

                    print (srr_acc, child.attrib['total_spots'])

                    return int(child.attrib['total_spots'])

        except:

            print ('error occured collecting spot count', srr_acc, error_count)

            time.sleep(10)

            error_count = error_count +1

# %%
data2 = my_list = list(df['acc'].unique())

spot_df = pd.DataFrame(data2, columns=['acc'])

# %%
spot_df['spot_count'] = spot_df.apply(get_spot_count, axis=1, args=['halsteadjs@nih.gov', 3])

# %%
spot_df.to_csv('spot_map.csv')

# %%
read_count_dict ={}

for row in spot_df.iterrows():
    read_count_dict[(row[1]['acc'])] = row[1]['spot_count']

# %%
def normalise(df):
    
    srr = df['acc']
    
    read_count = read_count_dict[srr]
    
    return read_count

# %%
df['read_count'] = df.apply(normalise, axis=1)

# %%
df.head()
# Out:
#    count             seq                                        file type  \
# 0      0  NM_001329964.1  aml_results/aml.SRR948635.sam.hitcount.txt  aml
# 1      0     NM_003722.4  aml_results/aml.SRR948635.sam.hitcount.txt  aml
# 2      0  NM_001329150.1  aml_results/aml.SRR948635.sam.hitcount.txt  aml
# 3      0  NM_001329149.1  aml_results/aml.SRR948635.sam.hitcount.txt  aml
# 4      0  NM_001329148.1  aml_results/aml.SRR948635.sam.hitcount.txt  aml
#
#          acc  read_count
# 0  SRR948635    17042498
# 1  SRR948635    17042498
# 2  SRR948635    17042498
# 3  SRR948635    17042498
# 4  SRR948635    17042498

# %%
def normalise_values(df):
    
    return (df['count'] / df['read_count']) * 1000000

# %%
df['normalised_count'] = df.apply(normalise_values, axis=1)

# %%
df.to_csv('alldata.normalised.zeroes.csv')

# %%
aml_df = df[df['type'] == 'aml']
control_df = df[df['type'] == 'control']

# %%
pivoted_aml = aml_df.pivot_table(index='acc',columns='seq', values='normalised_count')
pivoted_control = control_df.pivot_table(index='acc',columns='seq', values='normalised_count')

# %%
pivoted_aml.to_csv('aml.normalised.pivot.zeroes.csv')
pivoted_control.to_csv('control.normalised.pivot.zeroes.csv')

# %%
sns.barplot(x='type', y='normalised_count', data=df)
